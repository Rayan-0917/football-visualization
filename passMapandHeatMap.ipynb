# %% [markdown]
# <a href="https://colab.research.google.com/github/Rayan-0917/football-visualization/blob/main/passMapandHeatMap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install mplsoccer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.4/86.4 kB 3.8 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from mplsoccer.pitch import Pitch, VerticalPitch
import seaborn as sns

# %%
df=pd.read_csv('messibetis.csv')
df
# Out:
#    player  minute  second    x    y  type       outcome  endX  endY
# 0   messi      45       0   50   50  Pass    Successful    40    43
# 1   messi      45      25   63   48  Pass    Successful    75    83
# 2   messi      46       4   74   58  Pass    Successful    71    65
# 3   messi      46       7   76   68  Pass    Successful    95    78
# 4   messi      46      55  100    1  Pass  Unsuccessful    96    38
# 5   messi      47      42   73   25  Pass    Successful    70    54
# 6   messi      49      47   75   43  Pass  Unsuccessful    82    38
# 7   messi      50      10   79   31  Pass    Successful    87    24
# 8   messi      50      17   82   52  Pass    Successful    93    68
# 9   messi      50      24   98   62  Pass  Unsuccessful    98    61
# 10  messi      55      22   30   12  Pass    Successful    22    24
# 11  messi      56      24   38   42  Pass    Successful    37    51
# 12  messi      56      36   53   44  Pass    Successful    43    62
# ...

# %%
pitch = Pitch(half=False, pitch_type='opta', pitch_color='#22312b', line_color='#c7d5cc')
#pitch = Pitch(pitch_color='grass', line_color='white', stripe=True)
fig, ax = pitch.draw(figsize=(13.5, 8), constrained_layout=True, tight_layout=False)
fig.set_facecolor('#22312b')



for x in range(len(df['x'])):
  if(df['outcome'][x]=='Successful'):
    plt.plot((df['x'][x], df['endX'][x]), (df['y'][x], df['endY'][x]), color='green')
    plt.scatter(df['x'][x], df['y'][x], color='green')

  elif(df['outcome'][x]=='Unsuccessful'):
    plt.plot((df['x'][x], df['endX'][x]), (df['y'][x], df['endY'][x]), color='red')
    plt.scatter(df['x'][x], df['y'][x], color='red')

kde=sns.kdeplot(x=df['x'], y=df['y'], fill=True, shade_lowest=False, alpha=.5, n_levels=10, cmap='magma')



plt.title('Messi pass-map vs betis')
# Out:
# Text(0.5, 1.0, 'Messi pass-map vs betis')
